# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
df = pd.read_csv('../input/cleaned_daal2.csv')
df
# Out:
#          CDB ID               OSC Account Name Country Name  \
# 0       7425027                           1976           PE
# 1        523314                          37135           DO
# 2       1080194                          44988           AR
# 3       7561885                    50624412411           CR
# 4       7434745  ALLIANZ TECHNOLOGY OF AMERICA           US
# ...         ...                            ...          ...
# 127693  7568158                WREXHAM COUNCIL           GB
# 127694   647360      WYCHAVON DISTRICT COUNCIL           GB
# 127695  1316172       WYCOMBE DISTRICT COUNCIL           GB
# 127696  1473192           WYRE BOROUGH COUNCIL           GB
# 127697   956771   WYRE FOREST DISTRICT COUNCIL           GB
#
#        FY24 Account Segmentation      DAAL NB
# 0                       Longtail         1976
# 1                       Longtail        37135
# 2                       Longtail        44258
# 3                       Longtail  50624412411
# ...

# %%
pip install thefuzz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/1.7 MB ? eta -:--:--
#                                               0.0/1.7 MB 660.6 kB/s eta 0:00:03
#                                               0.0/1.7 MB 487.6 kB/s eta 0:00:04
#      -                                        0.1/1.7 MB 491.5 kB/s eta 0:00:04
#      --                                       0.1/1.7 MB 726.2 kB/s eta 0:00:03
#      --                                       0.1/1.7 MB 726.2 kB/s eta 0:00:03
#      ----                                     0.2/1.7 MB 778.2 kB/s eta 0:00:02
#      -----                                    0.3/1.7 MB 827.5 kB/s eta 0:00:02
#      -------                                  0.3/1.7 MB 910.2 kB/s eta 0:00:02
#      --------                                 0.4/1.7 MB 916.6 kB/s eta 0:00:02
#      ----------                               0.5/1.7 MB 994.6 kB/s eta 0:00:02
# ...
