# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
daal_df = pd.read_csv('../output/cleaned_daal2.csv')
daal_df.head(25)
# Out:
#      CDB ID                                   OSC Account Name Country Name  \
# 0   7425027                                               1976           PE
# 1    523314                                              37135           DO
# 2   1080194                                              44988           AR
# 3   7561885                                        50624412411           CR
# 4   7434745                      ALLIANZ TECHNOLOGY OF AMERICA           US
# 5   6863506                                      HARRIS COUNTY           US
# 6   7239941               ISSAM IMPORTACAO E EXPORTACAO EIRELI           BR
# 7   7234731                 RICHLAND COUNTY EMERGENCY SERVICES           US
# 8     11670         SUPERIOR COURT OF CALIFORNIAVENTURA COUNTY           US
# 9   1508091                                           TERADATA           US
# 10  7572078                        THOMAS M FRENCH LAW OFFICES           US
# 11  7470641                                         TIDY FILES           GS
# 12  2470066                                      AMERICAN BEEF           MX
# 13  2463882                             BTG PACTUAL CASA BOLSA           MX
# 14   472954                         CS RECURSOS GEOTERMICO ICE           CR
# 15  5874935                     ESCUELA SUPERIOR ARTES YUCATAN           MX
# 16  1259324                    MILLINGTON FIRST BAPTIST CHURCH           US
# 17   574225                                        PROALCO SAS           CO
# 18  2704208                           (IT) BUCKEYE DATA CENTER           US
# 19  6776451                          (IT) DISCOVER RWD III SSB           US
# 20  1254130  (NIH) NIAMS NATIONAL INSTITUTE OF ARTHRITIS MU...           US
# 21  7514132                    (SSC) IMMIGRATION REFUGEE BOARD           CA
# 22  7514507       (SSC) PUBLIC SERVICES AND PROCUREMENT CANADA           CA
# 23  1304214                                      COM MARKETING           US
# 24  2428733             : FONDO SOLIDARIDAD E INVERSION SOCIAL           CL
#
#    FY24 Account Segmentation                                 DAAL NB
# 0                   Longtail                                    1976
# 1                   Longtail                                   37135
# 2                   Longtail                                   44258
# 3                   Longtail                             50624412411
# 4                  Segment 2                                 ALLIANZ
# 5                  Segment 1                     COUNTY OF HARRIS TX
# 6                   Longtail    ISSAM IMPORTACAO E EXPORTACAO EIRELI
# 7                   Longtail      RICHLAND COUNTY EMERGENCY SERVICES
# 8                   Longtail                    COUNTY OF VENTURA CA
# 9                  Segment 1                                TERADATA
# 10                  Longtail                           THOMAS FRENCH
# 11                  Longtail                              TIDY FILES
# 12                  Longtail                           AMERICAN BEEF
# 13                  Longtail                      BTG PACTUAL MEXICO
# 14                  Longtail             C RECURSOS GEOTERMICO I C E
# 15                  Longtail       AA ESCUELA SUPERIOR ARTES YUCATAN
# 16                  Longtail      AA MILLINGTON FIRST BAPTIST CHURCH
# 17                  Longtail                          AA PROALCO SAS
# 18                 Segment 3                (IT) BUCKEYE DATA CENTER
# 19                 Segment 1             DISCOVER FINANCIAL SERVICES
# 20                 Segment 1  US DEPARTMENT OF HEALTH HUMAN SERVICES
# 21                 Segment 1                    GOVERNMENT OF CANADA
# 22                 Segment 1                    GOVERNMENT OF CANADA
# 23                 Segment 2                               COGNIZANT
# 24                  Longtail    FONDO SOLIDARIDAD E INVERSION SOCIAL

# %%
input_df = pd.read_csv('../output/cleaned_input.csv')
input_df
# Out:
#       CDB_ID  Party_NumberĿ         Account(Customer_Name) Country_Code_Only
# 0          1         230401               FLEXERA SOFTWARE                US
# 1          2         230402        TIANJIN SWCX TECHNOLOGY                CN
# 2          3         230403  SUNGARD AVAILABILITY SERVICES                IN
# 3          4         230404                    CLINSE LABS                IN
# 4          5         230405                          MYLAN                US
# ...      ...            ...                            ...               ...
# 5437   37164         235838                      JHU PRESS                US
# 5438   37191         235839                  LG CHEM KOREA                KR
# 5439   37218         235840      FPT TELECOM INTERNATIONAL                VN
# 5440   37245         235841              VIRGIN MANAGEMENT                GB
# 5441   37272         235842             MITSUI SEAFOODSLTD                JP
#
# [5442 rows x 4 columns]

# %% [markdown]
# ## Steps to process the uploaded input file and daal file
#     1. firstly read input file and daal file, store them in 2 different dataframes.
#     2. Iterate on 'input_file_df' and for each record from input file, find top 3 matching records from "daal_file_df" using fuzzyMatchPercentage. (threshold 80% above)
#     3. While finding top 3 matching records :
#         3.1. filter entire 'daal_file_df' dataframe accoring to common country names.
#         3.2. if out of 3 top matching records, if at any point found 100% fuzzMatched , skip processing of remaining daal file (time will be reduced)
#         3.3.
#     4. create 'new_df' with 2 columns as 'company name' (from input file) and 'similar company name' (from daal file), after done with step 2 and 3.
#     5. now calculate other 7 attributes i.e. values of simple ratio, partial ratio, token set ratio, ngram, charact_matching_percentage etc. and add these columns to 'new_df'
#     6. pass this 'new_df' to ML model for prediction of 'output' column as 0/1. And store only records with output = 1 (same) into final_df passed to flask application.

# %%
from fuzzywuzzy import process, fuzz

# Function to filter daal_df based on common country code
def filter_daal_df(country_code, reference_df):
    filtered_df = reference_df[reference_df['Country Name'] == country_code]
    # print(filtered_df)
    return filtered_df

# fuzzy ratio function
def calculate_fuzzy_ratio(str1, str2):
    return fuzz.ratio(str1, str2)

# Function to find top 3 matching records
def find_top_matches(row, reference_df, threshold=75):
    # Convert NaN values to empty strings in both columns
    query_str = str(row['Account(Customer_Name)']) if not pd.isna(row['Account(Customer_Name)']) else ''
    
    # Calculate fuzzy ratio for each record in reference_df and filter based on threshold
    reference_df['Fuzz Ratio'] = reference_df['OSC Account Name'].apply(lambda x: calculate_fuzzy_ratio(query_str, str(x)))
    
    # Check if a perfect match (fuzzy ratio of 100) is found **** (so we can skip remaining daal file search)
    perfect_match = reference_df[reference_df['Fuzz Ratio'] == 100].head(1)
    
    if not perfect_match.empty:
        # If a perfect match is found, skip further processing and return the result
        return pd.DataFrame({
            'Account(Customer_Name)': [query_str],
            'OSC Account Name': perfect_match['OSC Account Name'].tolist(),
            'Score': [100]
        })
    
    # Filter based on threshold
    filtered_matches = reference_df[reference_df['Fuzz Ratio'] > threshold]
    
    # Extract top 3 matches
    top_matches = filtered_matches.sort_values(by='Fuzz Ratio', ascending=False).head(3)
    
    # Return the result as a DataFrame
    result_df = pd.DataFrame({
        'Account(Customer_Name)': [query_str] * len(top_matches),
        'OSC Account Name': top_matches['OSC Account Name'].tolist(),
        'Score': top_matches['Fuzz Ratio'].tolist()
    })
    
    return result_df


# Function row-wise on the first 30 records of input_df
matched_df_list = []
for index, row in input_df.head(50).iterrows():
    # Filter daal_df based on the common country code
    country_code = row['Country_Code_Only']
    filtered_daal_df = filter_daal_df(country_code, daal_df)
    # print(filtered_daal_df)

    # Find top matches for the current row
    matches_df = find_top_matches(row, filtered_daal_df)
    matched_df_list.append(matches_df)

# Concatenate the list of DataFrames into a single DataFrame
matched_result_df = pd.concat(matched_df_list, ignore_index=True)

# Display the new DataFrame
print("Matched Result DataFrame (First 30 records from input_df):")
matched_result_df
# Out:
# Matched Result DataFrame (First 30 records from input_df):
#                               Account(Customer_Name)  \
# 0                                   FLEXERA SOFTWARE
# 1                            TIANJIN SWCX TECHNOLOGY
# 2                            TIANJIN SWCX TECHNOLOGY
# 3                            TIANJIN SWCX TECHNOLOGY
# 4                                        CLINSE LABS
# 5                                              MYLAN
# 6                                    COCHIN SHIPYARD
# 7                   KOTAK MAHINDRA GENERAL INSURANCE
# 8                                        GUJARAT GAS
# 9                       RAJCOMP INFORMATION SERVICES
# 10                      RAJCOMP INFORMATION SERVICES
# 11                             HATHWAY CABLE DATACOM
# 12                    BLACKROCK FINANCIAL MANAGEMENT
# 13                                 IPCA LABORATORIES
# 14                            CHARTER COMMUNICATIONS
# 15                                 COMPUTER SCIENCES
# 16                                   BNP PARIBAS CIB
# 17                                     AXA COLPATRIA
# 18                               HDFC LIFE INSURANCE
# 19                               TATA COMMUNICATIONS
# 20                               TATA COMMUNICATIONS
# 21                               TATA COMMUNICATIONS
# 22                                       MTN NIGERIA
# 23                  BLUECREST CAPITAL MANAGEMENT LLP
# 24                         OLAM INFORMATION SERVICES
# 25               TETRA PAK INFORMATION MANAGEMENT AB
# 26                              CATHOLIC SYRIAN BANK
# 27                       PT BANK MANDIRI PERSERO TBK
# 28                       PT BANK MANDIRI PERSERO TBK
# 29                                     SAUDI TELECOM
# 30                           WELLSTAR HEALTH SYSTEMS
# 31                                             COACH
# 32                                       ERICSSON AB
# 33                                      GEA GROUP AG
# 34                                   BANK OF AMERICA
# 35                            EMCURE PHARMACEUTICALS
# 36                            EMCURE PHARMACEUTICALS
# 37                            EMCURE PHARMACEUTICALS
# 38                               KOTAK MAHINDRA BANK
# 39                                           INFOSYS
# 40                              FERGUSON ENTERPRISES
# 41                                     HAMAD MEDICAL
# 42                                 SAUDI ELECTRICITY
# 43                         TATA CONSULTANCY SERVICES
# 44                            CENTRAL PROVIDENT FUND
# 45                                   CAPGEMINI INDIA
# 46  KING FAHD UNIVERSITY OF PETROLEUM MINERALS KFUPM
# 47                       BURUJ COOPERATIVE INSURANCE
# 48        MINISTRY OF COMMUNICATIONS AND INFORMATION
#
#                                      OSC Account Name  Score
# 0                                    FLEXERA SOFTWARE  100.0
# 1                             TIANJIN ENEN TECHNOLOGY   83.0
# 2                             TIANJIN AIMA TECHNOLOGY   83.0
# 3                  TIANJIN SWCX ELECTRONIC TECHNOLOGY   81.0
# 4                                           PINE LABS   80.0
# 5                                               MYLAN  100.0
# 6                                     COCHIN SHIPYARD  100.0
# 7                    KOTAK MAHINDRA GENERAL INSURANCE  100.0
# 8                                         GUJARAT GAS  100.0
# 9                         RAJCOMP INFORMATION SERVICE   98.0
# 10                          OLAM INFORMATION SERVICES   87.0
# 11                          HATHWAY CABLE AND DATACOM   91.0
# 12                     BLACKROCK FINANCIAL MANAGEMENT  100.0
# 13                                  IPCA LABORATORIES  100.0
# 14                             CHARTER COMMUNICATIONS  100.0
# 15                                  COMPUTER SCIENCES  100.0
# 16                                        BNP PARIBAS   85.0
# 17                                      AXA COLPATRIA  100.0
# 18                                HDFC LIFE INSURANCE  100.0
# 19                                 TATA COMMUNICATION   97.0
# 20                      TATA COMMUNICATIONS BPO INDIA   79.0
# 21                            RELIANCE COMMUNICATIONS   76.0
# 22                                        MTN NIGERIA  100.0
# 23                   BLUECREST CAPITAL MANAGEMENT LLP  100.0
# 24                          OLAM INFORMATION SERVICES  100.0
# 25                TETRA PAK INFORMATION MANAGEMENT AB  100.0
# 26                               CATHOLIC SYRIAN BANK  100.0
# 27                      PT BANK MANDIRI (PERSERO) TBK   96.0
# 28                      BANK MANDIRI (PERSERO) PT TBK   86.0
# 29                                  SAUDI TELECOM STC   87.0
# 30                            WELLSTAR HEALTH SYSTEMS  100.0
# 31                                              COACH  100.0
# 32                                        ERICSSON AB  100.0
# 33                                       GEA GROUP AG  100.0
# 34                                    BANK OF AMERICA  100.0
# 35                            ALEMBIC PHARMACEUTICALS   84.0
# 36                           GLENMARK PHARMACEUTICALS   83.0
# 37                            TORRENT PHARMACEUTICALS   80.0
# 38                                KOTAK MAHINDRA BANK  100.0
# 39                                            INFOSYS  100.0
# 40                               FERGUSON ENTERPRISES  100.0
# 41                                      HAMAD MEDICAL  100.0
# 42                                  SAUDI ELECTRICITY  100.0
# 43                          TATA CONSULTANCY SERVICES  100.0
# 44                             CENTRAL PROVIDENT FUND  100.0
# 45                                    CAPGEMINI INDIA  100.0
# 46  KING FAHAD UNIVERISTY FOR PETROLIOM MENERALS (...   86.0
# 47                 GULF GENERAL COOPERATIVE INSURANCE   79.0
# 48         MINISTRY OF COMMUNICATIONS AND INFORMATION  100.0

# %%
matched_result_df = matched_result_df.drop("Score", axis=1)
matched_result_df
# Out:
#                               Account(Customer_Name)  \
# 0                                   FLEXERA SOFTWARE
# 1                            TIANJIN SWCX TECHNOLOGY
# 2                            TIANJIN SWCX TECHNOLOGY
# 3                            TIANJIN SWCX TECHNOLOGY
# 4                                        CLINSE LABS
# 5                                              MYLAN
# 6                                    COCHIN SHIPYARD
# 7                   KOTAK MAHINDRA GENERAL INSURANCE
# 8                                        GUJARAT GAS
# 9                       RAJCOMP INFORMATION SERVICES
# 10                      RAJCOMP INFORMATION SERVICES
# 11                             HATHWAY CABLE DATACOM
# 12                    BLACKROCK FINANCIAL MANAGEMENT
# 13                                 IPCA LABORATORIES
# 14                            CHARTER COMMUNICATIONS
# 15                                 COMPUTER SCIENCES
# 16                                   BNP PARIBAS CIB
# 17                                     AXA COLPATRIA
# 18                               HDFC LIFE INSURANCE
# 19                               TATA COMMUNICATIONS
# 20                               TATA COMMUNICATIONS
# 21                               TATA COMMUNICATIONS
# 22                                       MTN NIGERIA
# 23                  BLUECREST CAPITAL MANAGEMENT LLP
# 24                         OLAM INFORMATION SERVICES
# 25               TETRA PAK INFORMATION MANAGEMENT AB
# 26                              CATHOLIC SYRIAN BANK
# 27                       PT BANK MANDIRI PERSERO TBK
# 28                       PT BANK MANDIRI PERSERO TBK
# 29                                     SAUDI TELECOM
# 30                           WELLSTAR HEALTH SYSTEMS
# 31                                             COACH
# 32                                       ERICSSON AB
# 33                                      GEA GROUP AG
# 34                                   BANK OF AMERICA
# 35                            EMCURE PHARMACEUTICALS
# 36                            EMCURE PHARMACEUTICALS
# 37                            EMCURE PHARMACEUTICALS
# 38                               KOTAK MAHINDRA BANK
# 39                                           INFOSYS
# 40                              FERGUSON ENTERPRISES
# 41                                     HAMAD MEDICAL
# 42                                 SAUDI ELECTRICITY
# 43                         TATA CONSULTANCY SERVICES
# 44                            CENTRAL PROVIDENT FUND
# 45                                   CAPGEMINI INDIA
# 46  KING FAHD UNIVERSITY OF PETROLEUM MINERALS KFUPM
# 47                       BURUJ COOPERATIVE INSURANCE
# 48        MINISTRY OF COMMUNICATIONS AND INFORMATION
#
#                                      OSC Account Name
# 0                                    FLEXERA SOFTWARE
# 1                             TIANJIN ENEN TECHNOLOGY
# 2                             TIANJIN AIMA TECHNOLOGY
# 3                  TIANJIN SWCX ELECTRONIC TECHNOLOGY
# 4                                           PINE LABS
# 5                                               MYLAN
# 6                                     COCHIN SHIPYARD
# 7                    KOTAK MAHINDRA GENERAL INSURANCE
# 8                                         GUJARAT GAS
# 9                         RAJCOMP INFORMATION SERVICE
# 10                          OLAM INFORMATION SERVICES
# 11                          HATHWAY CABLE AND DATACOM
# 12                     BLACKROCK FINANCIAL MANAGEMENT
# 13                                  IPCA LABORATORIES
# 14                             CHARTER COMMUNICATIONS
# 15                                  COMPUTER SCIENCES
# 16                                        BNP PARIBAS
# 17                                      AXA COLPATRIA
# 18                                HDFC LIFE INSURANCE
# 19                                 TATA COMMUNICATION
# 20                      TATA COMMUNICATIONS BPO INDIA
# 21                            RELIANCE COMMUNICATIONS
# 22                                        MTN NIGERIA
# 23                   BLUECREST CAPITAL MANAGEMENT LLP
# 24                          OLAM INFORMATION SERVICES
# 25                TETRA PAK INFORMATION MANAGEMENT AB
# 26                               CATHOLIC SYRIAN BANK
# 27                      PT BANK MANDIRI (PERSERO) TBK
# 28                      BANK MANDIRI (PERSERO) PT TBK
# 29                                  SAUDI TELECOM STC
# 30                            WELLSTAR HEALTH SYSTEMS
# 31                                              COACH
# 32                                        ERICSSON AB
# 33                                       GEA GROUP AG
# 34                                    BANK OF AMERICA
# 35                            ALEMBIC PHARMACEUTICALS
# 36                           GLENMARK PHARMACEUTICALS
# 37                            TORRENT PHARMACEUTICALS
# 38                                KOTAK MAHINDRA BANK
# 39                                            INFOSYS
# 40                               FERGUSON ENTERPRISES
# 41                                      HAMAD MEDICAL
# 42                                  SAUDI ELECTRICITY
# 43                          TATA CONSULTANCY SERVICES
# 44                             CENTRAL PROVIDENT FUND
# 45                                    CAPGEMINI INDIA
# 46  KING FAHAD UNIVERISTY FOR PETROLIOM MENERALS (...
# 47                 GULF GENERAL COOPERATIVE INSURANCE
# 48         MINISTRY OF COMMUNICATIONS AND INFORMATION

# %%
# calculating the ratio values as attributes
# 'Simple Ratio', 'partial Ratio', 'Token Set Ratio', 'word match percentage', 'last word match', 'character_matching_percentage', 'ngrams'
from feature_extraction import calculate_simple_ratio, calculate_partial_ratio, calculate_token_set_ratio, calculate_word_matching_percentage, last_word_match, character_matching_percentage, calculate_ngrams_similarity

# Extracting features (ratios) from the fuzzy matching scores
matched_result_df['Simple Ratio'] = matched_result_df.apply(lambda row: calculate_simple_ratio(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 
matched_result_df['partial Ratio'] = matched_result_df.apply(lambda row: calculate_partial_ratio(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 
matched_result_df['Token Set Ratio'] = matched_result_df.apply(lambda row: calculate_token_set_ratio(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 
matched_result_df['word match percentage'] = matched_result_df.apply(lambda row: calculate_word_matching_percentage(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 
matched_result_df['last word match'] = matched_result_df.apply(lambda row: last_word_match(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 
matched_result_df['last word match'] = matched_result_df['last word match'].astype(int)
matched_result_df['character_matching_percentage'] = matched_result_df.apply(lambda row: character_matching_percentage(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 
matched_result_df['ngrams'] = matched_result_df.apply(lambda row: calculate_ngrams_similarity(row['Account(Customer_Name)'], row['OSC Account Name']), axis=1) 

# Display the DataFrame with predictions
print("DataFrame with Predictions:")
matched_result_df.head(10)
# Out:
# DataFrame with Predictions:
#              Account(Customer_Name)                    OSC Account Name  \
# 0                  FLEXERA SOFTWARE                    FLEXERA SOFTWARE
# 1           TIANJIN SWCX TECHNOLOGY             TIANJIN ENEN TECHNOLOGY
# 2           TIANJIN SWCX TECHNOLOGY             TIANJIN AIMA TECHNOLOGY
# 3           TIANJIN SWCX TECHNOLOGY  TIANJIN SWCX ELECTRONIC TECHNOLOGY
# 4                       CLINSE LABS                           PINE LABS
# 5                             MYLAN                               MYLAN
# 6                   COCHIN SHIPYARD                     COCHIN SHIPYARD
# 7  KOTAK MAHINDRA GENERAL INSURANCE    KOTAK MAHINDRA GENERAL INSURANCE
# 8                       GUJARAT GAS                         GUJARAT GAS
# 9      RAJCOMP INFORMATION SERVICES         RAJCOMP INFORMATION SERVICE
#
#    Simple Ratio  partial Ratio  Token Set Ratio  word match percentage  \
# 0           100            100              100             100.000000
# 1            83             83               88              50.000000
# 2            83             83               88              50.000000
# 3            81             70              100              75.000000
# 4            80             89               80              33.333333
# 5           100            100              100             100.000000
# 6           100            100              100             100.000000
# 7           100            100              100             100.000000
# 8           100            100              100             100.000000
# 9            98            100               98              50.000000
#
#    last word match  character_matching_percentage    ngrams
# 0                1                     100.000000  1.000000
# 1                1                      82.608696  0.680000
# 2                1                      82.608696  0.629630
# 3                1                      38.235294  0.687500
# 4                1                       0.000000  0.500000
# 5                1                     100.000000  1.000000
# 6                1                     100.000000  1.000000
# 7                1                     100.000000  1.000000
# 8                1                     100.000000  1.000000
# 9                0                      96.428571  0.962963

# %%
# training svm model on 'cleaned_training_dataset' csv file having newly added more extra features all 16 
df = pd.read_csv('../output/cleaned_training_dataset.csv')
# df

# %%
# for training model, we need to split the dataframe and also its features
from sklearn.model_selection import train_test_split
# Separate features and target variable
features = [ 'Simple Ratio', 'partial Ratio', 'Token Set Ratio', 'word match percentage', 'last word match', 'character_matching_percentage', 'ngrams']
xn = df[features] #independent features (input columns)
yn = df['Target'] #dependent feature (output column)
Xn_train, Xn_test, yn_train, yn_test = train_test_split(xn, yn, test_size=0.3, random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Customizing Kernel Parameters: For both RBF and polynomial kernels, there are additional parameters you can tune, such as gamma for RBF
# Example with RBF kernel and customized gamma value = 0.001
svm_model_rbf_custom = SVC(kernel='poly', gamma=0.001)  # Try different gamma values, we got 0.001 as best gamma value
svm_model_rbf_custom.fit(Xn_train, yn_train)

yn_pred_rbf_custom = svm_model_rbf_custom.predict(Xn_test)

accuracy_rbf_custom = accuracy_score(yn_test, yn_pred_rbf_custom)
report_rbf_custom = classification_report(yn_test, yn_pred_rbf_custom)
print(f"Accuracy (RBF Kernel - Customized Gamma): {accuracy_rbf_custom}")
# print("Classification Report (RBF Kernel - Customized Gamma):\n", report_rbf_custom)
# Out:
# Accuracy (RBF Kernel - Customized Gamma): 0.7593582887700535

# %%
# for ML model prediction we have to pass only 7columns attribute values of ratios
# skipping first 2 columns here:
temp_result_df = matched_result_df[[ 'Simple Ratio', 'partial Ratio', 'Token Set Ratio', 'word match percentage', 'last word match', 'character_matching_percentage', 'ngrams']]

# Predict using the ML model
temp_result_df['output'] = svm_model_rbf_custom.predict(temp_result_df)
matched_result_df['output'] = temp_result_df['output']
temp_result_df.head(10)
# Out:
#    Simple Ratio  partial Ratio  Token Set Ratio  word match percentage  \
# 0           100            100              100             100.000000
# 1            83             83               88              50.000000
# 2            83             83               88              50.000000
# 3            81             70              100              75.000000
# 4            80             89               80              33.333333
# 5           100            100              100             100.000000
# 6           100            100              100             100.000000
# 7           100            100              100             100.000000
# 8           100            100              100             100.000000
# 9            98            100               98              50.000000
#
#    last word match  character_matching_percentage    ngrams  output
# 0                1                     100.000000  1.000000       0
# 1                1                      82.608696  0.680000       0
# 2                1                      82.608696  0.629630       0
# 3                1                      38.235294  0.687500       1
# 4                1                       0.000000  0.500000       1
# 5                1                     100.000000  1.000000       0
# 6                1                     100.000000  1.000000       0
# 7                1                     100.000000  1.000000       0
# 8                1                     100.000000  1.000000       0
# 9                0                      96.428571  0.962963       1

# %%
matched_result_df
# Out:
#                               Account(Customer_Name)  \
# 0                                   FLEXERA SOFTWARE
# 1                            TIANJIN SWCX TECHNOLOGY
# 2                            TIANJIN SWCX TECHNOLOGY
# 3                            TIANJIN SWCX TECHNOLOGY
# 4                                        CLINSE LABS
# 5                                              MYLAN
# 6                                    COCHIN SHIPYARD
# 7                   KOTAK MAHINDRA GENERAL INSURANCE
# 8                                        GUJARAT GAS
# 9                       RAJCOMP INFORMATION SERVICES
# 10                      RAJCOMP INFORMATION SERVICES
# 11                             HATHWAY CABLE DATACOM
# 12                    BLACKROCK FINANCIAL MANAGEMENT
# 13                                 IPCA LABORATORIES
# 14                            CHARTER COMMUNICATIONS
# 15                                 COMPUTER SCIENCES
# 16                                   BNP PARIBAS CIB
# 17                                     AXA COLPATRIA
# 18                               HDFC LIFE INSURANCE
# 19                               TATA COMMUNICATIONS
# 20                               TATA COMMUNICATIONS
# 21                               TATA COMMUNICATIONS
# 22                                       MTN NIGERIA
# 23                  BLUECREST CAPITAL MANAGEMENT LLP
# 24                         OLAM INFORMATION SERVICES
# 25               TETRA PAK INFORMATION MANAGEMENT AB
# 26                              CATHOLIC SYRIAN BANK
# 27                       PT BANK MANDIRI PERSERO TBK
# 28                       PT BANK MANDIRI PERSERO TBK
# 29                                     SAUDI TELECOM
# 30                           WELLSTAR HEALTH SYSTEMS
# 31                                             COACH
# 32                                       ERICSSON AB
# 33                                      GEA GROUP AG
# 34                                   BANK OF AMERICA
# 35                            EMCURE PHARMACEUTICALS
# 36                            EMCURE PHARMACEUTICALS
# 37                            EMCURE PHARMACEUTICALS
# 38                               KOTAK MAHINDRA BANK
# 39                                           INFOSYS
# 40                              FERGUSON ENTERPRISES
# 41                                     HAMAD MEDICAL
# 42                                 SAUDI ELECTRICITY
# 43                         TATA CONSULTANCY SERVICES
# 44                            CENTRAL PROVIDENT FUND
# 45                                   CAPGEMINI INDIA
# 46  KING FAHD UNIVERSITY OF PETROLEUM MINERALS KFUPM
# 47                       BURUJ COOPERATIVE INSURANCE
# 48        MINISTRY OF COMMUNICATIONS AND INFORMATION
#
#                                      OSC Account Name  Simple Ratio  \
# 0                                    FLEXERA SOFTWARE           100
# 1                             TIANJIN ENEN TECHNOLOGY            83
# 2                             TIANJIN AIMA TECHNOLOGY            83
# 3                  TIANJIN SWCX ELECTRONIC TECHNOLOGY            81
# 4                                           PINE LABS            80
# 5                                               MYLAN           100
# 6                                     COCHIN SHIPYARD           100
# 7                    KOTAK MAHINDRA GENERAL INSURANCE           100
# 8                                         GUJARAT GAS           100
# 9                         RAJCOMP INFORMATION SERVICE            98
# 10                          OLAM INFORMATION SERVICES            87
# 11                          HATHWAY CABLE AND DATACOM            91
# 12                     BLACKROCK FINANCIAL MANAGEMENT           100
# 13                                  IPCA LABORATORIES           100
# 14                             CHARTER COMMUNICATIONS           100
# 15                                  COMPUTER SCIENCES           100
# 16                                        BNP PARIBAS            85
# 17                                      AXA COLPATRIA           100
# 18                                HDFC LIFE INSURANCE           100
# 19                                 TATA COMMUNICATION            97
# 20                      TATA COMMUNICATIONS BPO INDIA            79
# 21                            RELIANCE COMMUNICATIONS            76
# 22                                        MTN NIGERIA           100
# 23                   BLUECREST CAPITAL MANAGEMENT LLP           100
# 24                          OLAM INFORMATION SERVICES           100
# 25                TETRA PAK INFORMATION MANAGEMENT AB           100
# 26                               CATHOLIC SYRIAN BANK           100
# 27                      PT BANK MANDIRI (PERSERO) TBK            96
# 28                      BANK MANDIRI (PERSERO) PT TBK            86
# 29                                  SAUDI TELECOM STC            87
# 30                            WELLSTAR HEALTH SYSTEMS           100
# 31                                              COACH           100
# 32                                        ERICSSON AB           100
# 33                                       GEA GROUP AG           100
# 34                                    BANK OF AMERICA           100
# 35                            ALEMBIC PHARMACEUTICALS            84
# 36                           GLENMARK PHARMACEUTICALS            83
# 37                            TORRENT PHARMACEUTICALS            80
# 38                                KOTAK MAHINDRA BANK           100
# 39                                            INFOSYS           100
# 40                               FERGUSON ENTERPRISES           100
# 41                                      HAMAD MEDICAL           100
# 42                                  SAUDI ELECTRICITY           100
# 43                          TATA CONSULTANCY SERVICES           100
# 44                             CENTRAL PROVIDENT FUND           100
# 45                                    CAPGEMINI INDIA           100
# 46  KING FAHAD UNIVERISTY FOR PETROLIOM MENERALS (...            86
# 47                 GULF GENERAL COOPERATIVE INSURANCE            79
# 48         MINISTRY OF COMMUNICATIONS AND INFORMATION           100
#
#     partial Ratio  Token Set Ratio  word match percentage  last word match  \
# 0             100              100             100.000000                1
# 1              83               88              50.000000                1
# 2              83               88              50.000000                1
# 3              70              100              75.000000                1
# 4              89               80              33.333333                1
# 5             100              100             100.000000                1
# 6             100              100             100.000000                1
# 7             100              100             100.000000                1
# 8             100              100             100.000000                1
# 9             100               98              50.000000                0
# 10             94               89              50.000000                1
# 11             81              100              75.000000                1
# 12            100              100             100.000000                1
# 13            100              100             100.000000                1
# 14            100              100             100.000000                1
# 15            100              100             100.000000                1
# 16            100              100              66.666667                0
# 17            100              100             100.000000                1
# 18            100              100             100.000000                1
# 19            100               97              33.333333                0
# 20            100              100              50.000000                0
# 21             84               85              33.333333                1
# 22            100              100             100.000000                1
# 23            100              100             100.000000                1
# 24            100              100             100.000000                1
# 25            100              100             100.000000                1
# 26            100              100             100.000000                1
# 27             93              100              66.666667                1
# 28             81              100              66.666667                1
# 29            100              100              66.666667                0
# 30            100              100             100.000000                1
# 31            100              100             100.000000                1
# 32            100              100             100.000000                1
# 33            100              100             100.000000                1
# 34            100              100             100.000000                1
# 35             88               84              33.333333                1
# 36             86               83              33.333333                1
# 37             82               81              33.333333                1
# 38            100              100             100.000000                1
# 39            100              100             100.000000                1
# 40            100              100             100.000000                1
# 41            100              100             100.000000                1
# 42            100              100             100.000000                1
# 43            100              100             100.000000                1
# 44            100              100             100.000000                1
# 45            100              100             100.000000                1
# 46             83               84               7.692308                0
# 47             85               88              40.000000                1
# 48            100              100             100.000000                1
#
#     character_matching_percentage    ngrams  output
# 0                      100.000000  1.000000       0
# 1                       82.608696  0.680000       0
# 2                       82.608696  0.629630       0
# 3                       38.235294  0.687500       1
# 4                        0.000000  0.500000       1
# 5                      100.000000  1.000000       0
# 6                      100.000000  1.000000       0
# 7                      100.000000  1.000000       0
# 8                      100.000000  1.000000       0
# 9                       96.428571  0.962963       1
# 10                       0.000000  0.645161       1
# 11                      56.000000  0.826087       1
# 12                     100.000000  1.000000       0
# 13                     100.000000  1.000000       0
# 14                     100.000000  1.000000       0
# 15                     100.000000  1.000000       0
# 16                      73.333333  0.769231       1
# 17                     100.000000  1.000000       0
# 18                     100.000000  1.000000       0
# 19                      94.736842  0.937500       1
# 20                      65.517241  0.615385       1
# 21                       4.347826  0.583333       0
# 22                     100.000000  1.000000       0
# 23                     100.000000  1.000000       0
# 24                     100.000000  1.000000       0
# 25                     100.000000  1.000000       0
# 26                     100.000000  1.000000       0
# 27                      55.172414  0.785714       0
# 28                       3.448276  0.785714       0
# 29                      76.470588  0.750000       1
# 30                     100.000000  1.000000       0
# 31                     100.000000  1.000000       0
# 32                     100.000000  1.000000       0
# 33                     100.000000  1.000000       0
# 34                     100.000000  1.000000       0
# 35                       0.000000  0.640000       1
# 36                       0.000000  0.555556       1
# 37                       0.000000  0.592593       1
# 38                     100.000000  1.000000       0
# 39                     100.000000  1.000000       0
# 40                     100.000000  1.000000       0
# 41                     100.000000  1.000000       0
# 42                     100.000000  1.000000       0
# 43                     100.000000  1.000000       0
# 44                     100.000000  1.000000       0
# 45                     100.000000  1.000000       0
# 46                      23.076923  0.540984       0
# 47                       2.941176  0.588235       0
# 48                     100.000000  1.000000       0

# %%
# # Taking only the records with 'output' = 1 (i.e. same company name) into resultant_df with only 3 feilds
# filtered_df = matched_result_df[matched_result_df['output'] == 1]

# # Display the final DataFrame
# print("Filtered DataFrame:")
# filtered_df[['Account(Customer_Name)', 'OSC Account Name', 'output']]
